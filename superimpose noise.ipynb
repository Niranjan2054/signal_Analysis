# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import math as m
x = np.arange(0,4*m.pi,0.01)
y = 20*np.sin(x)
plt.plot(x,y)
plt.show()

# %%
#noise
noise = np.random.randn(1,len(x))

# %%
len(noise[0])
plt.plot(x,noise[0])

# %%
Rec_sig = noise[0] + y
plt.plot(x,Rec_sig)
