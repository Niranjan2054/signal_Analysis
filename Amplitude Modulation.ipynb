# %%
from matplotlib import pyplot as plt
import numpy as np
import math

# %%
x = np.arange(0,0.0005,0.000000001)

# %%
fc = 100000
fm = 5000

# %%
m = np.sin(2*np.pi*fm*x)

# %%
plt.plot(x,m)

# %%
c = np.sin(2*np.pi*fc*x)

# %%
plt.plot(x,c)

# %%
am = (1 + 1.5*np.sin(2*np.pi*fc*x))*np.sin(2*np.pi*fm*x)

# %%
plt.plot(x,am)

# %%
am = (1 + 1*np.sin(2*np.pi*fc*x))*np.sin(2*np.pi*fm*x)

# %%
plt.plot(x,am)

# %%
am = (1 + .5*np.sin(2*np.pi*fc*x))*np.sin(2*np.pi*fm*x)

# %%
plt.plot(x,am)
